# %%
import pandas as pd

# %%
df=pd.read_csv("HousingData.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df=df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\dmdik\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dmdik\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dmdik\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dmdik\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dmdik\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
x=df.drop(columns=["MEDV"])

# %%
y=df["MEDV"]

# %%
x.head(1)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        B  LSTAT
# 0  396.9   4.98

# %%
y[0]
# Out:
# 24.0

# %%
x.shape
# Out:
# (506, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
x_train.shape,x_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 x_train.shape,x_test.shape
#
# NameError: name 'x_train' is not defined

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape,x_test.shape
# Out:
# ((354, 13), (152, 13))

# %%
x_train.head
# Out:
# <bound method NDFrame.head of         CRIM    ZN      INDUS  CHAS    NOX     RM        AGE     DIS  RAD  \
# 223  0.61470   0.0   6.200000   0.0  0.507  6.618  80.800000  3.2721    8
# 270  0.29916  20.0   6.960000   0.0  0.464  5.856  42.100000  4.4290    3
# 320  0.16760   0.0   7.380000   0.0  0.493  6.426  52.300000  4.5404    5
# 327  0.24103   0.0   7.380000   0.0  0.493  6.083  43.700000  5.4159    5
# 305  0.05479  33.0  11.083992   0.0  0.472  6.616  58.100000  3.3700    7
# ..       ...   ...        ...   ...    ...    ...        ...     ...  ...
# 446  6.28807   0.0  18.100000   0.0  0.740  6.341  96.400000  2.0720   24
# 173  0.09178   0.0  11.083992   0.0  0.510  6.416  68.518519  2.6463    5
# 347  0.01870  85.0   4.150000   0.0  0.429  6.516  27.700000  8.5353    4
# 421  7.02259   0.0  18.100000   0.0  0.718  6.006  95.300000  1.8746   24
# 368  4.89822   0.0  18.100000   0.0  0.631  4.970  68.518519  1.3325   24
#
#      TAX  PTRATIO       B  LSTAT
# 223  307     17.4  396.90   7.60
# 270  223     18.6  388.65  13.00
# 320  287     19.6  396.90   7.20
# 327  287     19.6  396.90  12.79
# 305  222     18.4  393.36   8.93
# ..   ...      ...     ...    ...
# 446  666     20.2  318.01  17.79
# 173  296     16.6  395.50   9.04
# 347  351     17.9  392.43   6.36
# 421  666     20.2  319.98  15.70
# 368  666     20.2  375.52   3.26
#
# [354 rows x 13 columns]>

# %%
x_train.head()
# Out:
#         CRIM    ZN      INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 223  0.61470   0.0   6.200000   0.0  0.507  6.618  80.8  3.2721    8  307
# 270  0.29916  20.0   6.960000   0.0  0.464  5.856  42.1  4.4290    3  223
# 320  0.16760   0.0   7.380000   0.0  0.493  6.426  52.3  4.5404    5  287
# 327  0.24103   0.0   7.380000   0.0  0.493  6.083  43.7  5.4159    5  287
# 305  0.05479  33.0  11.083992   0.0  0.472  6.616  58.1  3.3700    7  222
#
#      PTRATIO       B  LSTAT
# 223     17.4  396.90   7.60
# 270     18.6  388.65  13.00
# 320     19.6  396.90   7.20
# 327     19.6  396.90  12.79
# 305     18.4  393.36   8.93

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 3.637317048012187

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 29.397192911618024

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, label="Ev Fiyat Tahminleri", alpha=0.6)
plt.xlabel("Gerçek Ev Fiyatları")  # <-- 'plt.label' değil 'plt.xlabel' olmalı
plt.ylabel("Tahmin Edilen Fiyatlar")

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot([min_val, max_val], [min_val, max_val], color="red", linestyle="--")

plt.legend()
plt.show()

# %%
import pandas as pd

# %%
new_house = {
    "CRIM": 0.09,
    "ZN": 0.0,
    "INDUS": 11.083992,
    "CHAS": 0.0,
    "NOX": 0.51,
    "RM": 6.417,
    "AGE": 68.5,
    "DIS": 2.64,
    "RAD": 5,
    "TAX": 296,
    "PTRATIO": 16.6,
    "B": 395.5,
    "LSTAT": 9.04
}



new_house_df=pd.DataFrame([new_house])
new_house_df
# Out:
#    CRIM   ZN      INDUS  CHAS   NOX     RM   AGE   DIS  RAD  TAX  PTRATIO  \
# 0  0.09  0.0  11.083992   0.0  0.51  6.417  68.5  2.64    5  296     16.6
#
#        B  LSTAT
# 0  395.5   9.04

# %%
model.predict(new_house_df)
# Out:
# array([29.14820781])

# %%
coef_df = pd.DataFrame(model.coef_, x.columns, columns=["Katsayı"])
coef_df
# Out:
#            Katsayı
# CRIM     -0.087356
# ZN        0.049563
# INDUS    -0.047383
# CHAS      0.826455
# NOX     -15.036137
# RM        3.499846
# AGE      -0.009838
# DIS      -1.566880
# RAD       0.378177
# TAX      -0.018889
# PTRATIO  -0.983570
# B         0.010083
# LSTAT    -0.433204
